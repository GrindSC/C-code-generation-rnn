# %%
# !pip install -q tokenizers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 42.0 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional, Dropout, LSTM, Embedding, Masking
from tokenizers import Tokenizer, decoders, models, normalizers, pre_tokenizers, trainers, processors
from sklearn.model_selection import train_test_split
import pickle
# Out:
# Mounted at /content/drive

# %%
path='/Data/java_train'
nl_tokenizer=Tokenizer(models.WordPiece(unk_token='[UNK]')).from_file(f'{path}/nl_tokenizer.json')
code_tokenizer=Tokenizer(models.WordPiece(unk_token='[UNK]')).from_file(f'{path}/code_tokenizer.json')

input_vocab_size=nl_tokenizer.get_vocab_size()
output_vocab_size=code_tokenizer.get_vocab_size()
X_train=np.load(f'{path}/X_train.npy',allow_pickle=True)
y_train=np.load(f'{path}/y_train.npy',allow_pickle=True)
X_test=np.load(f'{path}/X_test.npy',allow_pickle=True)
y_test=np.load(f'{path}/y_test.npy',allow_pickle=True)
X_val=np.load(f'{path}/X_val.npy',allow_pickle=True)
y_val=np.load(f'{path}/y_val.npy',allow_pickle=True)
model=tf.keras.models.load_model(f'{path}/java_model.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 149, 1)            0
#
#  bidirectional (Bidirectiona  (None, 298)              179992
#  l)
#
#  repeat_vector (RepeatVector  (None, 153, 298)         0
#  )
#
#  lstm_1 (LSTM)               (None, 153, 512)          1660928
#
#  lstm_2 (LSTM)               (None, 153, 1024)         6295552
#
#  dropout (Dropout)           (None, 153, 1024)         0
#
#  time_distributed (TimeDistr  (None, 153, 1024)        1049600
#  ibuted)
#
#  dropout_1 (Dropout)         (None, 153, 1024)         0
#
#  time_distributed_1 (TimeDis  (None, 153, 8000)        8200000
#  tributed)
#
# =================================================================
# Total params: 17,386,072
# Trainable params: 17,386,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
def predict(sample_num,test_subset=True):
  if test_subset:
    y_pred = model.predict(np.expand_dims(X_test[sample_num],axis=0),verbose=0)
    y_pred = np.argmax(y_pred, axis=-1) 
    print(nl_tokenizer.decode(X_test[sample_num]))
    print(code_tokenizer.decode(y_pred[0]))
    print(code_tokenizer.decode(y_test[sample_num]))
  else:
    y_pred = model.predict(np.expand_dims(X_train[sample_num],axis=0),verbose=0)
    y_pred = np.argmax(y_pred, axis=-1)
    print(nl_tokenizer.decode(X_train[sample_num]))
    print(code_tokenizer.decode(y_pred[0]))
    print(code_tokenizer.decode(y_train[sample_num]))

# %%
predict(26)
# Out:
# shutp down motechschedulerfactorybean. concode_field_sep applicationcontext applicationcontext concode_elem_sep properties schedulerproperties concode_elem_sep schedulerfactorybean schedulerfactorybean concode_field_sep void init concode_elem_sep boolean getbooleanwithdmfault concode_elem_sep scheduler getquart4scheduler concode_elem_sep schedulerfactorybean getquart4schedulerfactorybean
# void function ( ) { try { schedulerfactorybean ( destroy ( ) ; } scheduler schedulerexception ( ) ) ) ) scheduler scheduler scheduler scheduler ( ( ) ) ( ( ( ( ( ( ( } }
# void function ( ) { try { schedulerfactorybean. destroy ( ) ; } catch ( schedulerexception loc0 ) { throw new schedulershutdownexception ( "srini_string", loc0 ) ; } }

# %%
predict(10,False)
# Out:
# check for problems in a reader which contains javascript source. concode_field_sep scriptableobject scope concode_elem_sep map<option_object> options concode_elem_sep contextfactory contextfactory concode_field_sep map<string,integer> getdatamemberp concode_elem_sep void addoption concode_elem_sep void addoption concode_elem_sep void resetoptions concode_elem_sep jslintresult buildresults concode_elem_sep string callreport concode_elem_sep scriptable optionsasjavascriptobject concode_elem_sep string report concode_elem_sep string report concode_elem_sep void dolina concode_elem_sep jsidentifier convert concode_elem_sep string convert concode_elem_sep jsfunction convert concode_elem_sep string getedition concode_elem_sep list<issuek readerrorp
# jsadetresuuc function ( string arg0, string arg1 ) { return lin lin lin arg0, util.tostringtostringtostring util ) ) ) ; } ( ( ( ( ) ) ) ) ) ) ) ) ) ) return return } } } } } } } } } } } } }
# jsadetresuuc function ( string arg0, reader arg1 ) { return linc ( arg0, util. readertostring ( arg1 ) ) ; }
